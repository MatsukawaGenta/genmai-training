# %% [markdown]
# # 4. 多変数関数の微分
# # 4. Differentiation of multivariate functions

# %%
# 必要ライブラリの宣言
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
# L(u, v) = 3u^2 * 3v^2 - uv + 7u - 7v + 10
def L(u, v):
    return 3 * u**2 + 3 * v**2 - u*v + 7*u - 7*v + 10

# %%
# Lu(u, v) = 6u - v7
def Lu(u, v):
    return 6* u - v + 7

# %%
# Lv(u, v) = - u + 6v - 7
def Lv(u, v):
    return -u + 6 * v - 7

# %%
# Check return
L(-1,1)
# Out:
# 3

# %%
L(0,2)
# Out:
# 8

# %%
Lu(0,0)
# Out:
# 7

# %%
Lv(0,0)
# Out:
# -7

# %% [markdown]
# # 切断面グラフ
# # Cut plane graph

# %%
# fig04-04 3D graph and cut

# Make Z = L(U, V)
u = np.linspace(0.2, 5, 21)     # linespace(start, stop, num)
v = np.linspace(0.2, 5, 21)
U, V = np.meshgrid(u, v)        # U: X points of grid , V: Y points of grid
Z = L(U, V)

# Make L(u, 0), L(0, v) for showing line
uu = np.linspace(-5, 5, 41)
vv = np.linspace(-5, 5, 41)
zz = np.zeros(uu.shape)
Luu = L(uu, zz)     # L(u, 0)
Lvv = L(zz, vv)     # L(0, v)

# Make Luu2, Lvv2 for showing surface of cut
uu2 = np.vstack((uu, uu))
vv2 = np.vstack((vv, vv))
zz2 = np.vstack((zz, zz))
Luu2 = np.vstack((Luu, zz))
Lvv2 = np.vstack((Lvv, zz))

# 関数グラフのみ
# Only the graph of function

# Set figure
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.set_zlim(0, 250)
ax.view_init(50, 240)

# Set labels
ax.set_xlabel('$u$', fontsize=14)
ax.set_ylabel('$v$', fontsize=14)
ax.set_zlabel('$L(u,v)$', fontsize=14)

# Set grid
ax.xaxis._axinfo["grid"]['linewidth'] = 2.
ax.yaxis._axinfo["grid"]['linewidth'] = 2.
ax.zaxis._axinfo["grid"]['linewidth'] = 2.
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)

# Show surface of U, V and Z
ax.plot_surface(U, V, Z, rstride=1, cstride=1, cmap='Blues', 
                linewidth=0, shade=False, antialiased=False)

# Show surface of cut
ax.plot_surface(uu2, zz2, Luu2, color='white', linewidth=0, shade=False)
ax.plot_surface(zz2, vv2, Lvv2, color='white',linewidth=0, shade=False)

# Show line of L(u, 0) and L(0, v) 
ax.plot3D(uu, zz, Luu,c='k', lw=3, linestyle='-', label='$z = L(u, 0)$')
ax.plot3D(zz, vv, Lvv,c='k', lw=3, linestyle='--', label='$z = L(0, v)$')

ax.legend()
plt.show()

# %% [markdown]
# # 勾配降下法

# %%
# Make Z = L(U, V)
u = np.linspace(-5, 5, 501)
v = np.linspace(-5, 5, 501)
U, V = np.meshgrid(u, v)       # U: X points of grid , V: Y points of grid
Z = L(U, V)

# 勾配降下法のシミュレーション
# The simulation of gradient descent

# Set initial point
W = np.array([4.0, 4.0])    # matrix[4.0, 4.0]
W1 = [W[0]]     # W[0] = 4.0
W2 = [W[1]]     # W[1] = 4.0

# Calculate W, W1, and W2
N = 21
alpha = 0.05
for i in range(N):
    # [uk+1, vk+1] = [uk, vk] - α[Lu(uk, vk), Lv(uk, vk)]
    W = W - alpha *np.array([Lu(W[0], W[1]), Lv(W[0], W[1])])
    W1.append(W[0])
    W2.append(W[1])

print(W1)
print(W2)
# Out:
# [4.0, 2.65, 1.6724999999999999, 0.9621249999999999, 0.44413125, 0.06524781249999989, -0.2126670468750001, -0.41704217421875006, -0.5676838585546875, -0.6789493420449219, -0.7612831978174806, -0.8223086726975732, -0.8676065828405808, -0.9012737380367462, -0.9263250241166615, -0.9449840864704123, -0.9588942718017048, -0.9692722383680608, -0.9770201762119539, -0.9828080304923059, -0.9871339067859007, -0.9903685546352619]
# [4.0, 3.35, 2.8274999999999997, 2.4128749999999997, 2.0871187499999997, 1.8331896874999998, 1.6364951718749998, 1.4849132679687498, 1.3685871788671873, 1.2796268322792967, 1.2117913154932616, 1.1601897609544092, 1.1210173990332077, 1.0913318501812164, 1.068868608225014, 1.0518917745516767, 1.039075037862653, 1.0294078129137718, 1.0221218571212372, 1.0166342911742683, 1.0125036022973726, 1.0093958262688658]

# %% [markdown]
# ## 関数グラフ

# %%
n_loop = 0

# 関数グラフのみ
# Only the graph of function

# fig04-03 left

WW1 = np.array(W1[:n_loop])
WW2 = np.array(W2[:n_loop])
ZZ = L(WW1, WW2)
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.set_zlim(0,250)
ax.view_init(50, 240)
ax.set_xlabel('u', fontsize=14)
ax.set_ylabel('v', fontsize=14)
ax.set_zlabel('L(u,v)', fontsize=14)
ax.xaxis._axinfo["grid"]['linewidth'] = 2.
ax.yaxis._axinfo["grid"]['linewidth'] = 2.
ax.zaxis._axinfo["grid"]['linewidth'] = 2.
ax.contour3D(U, V, Z, 100, cmap='Blues', alpha=1.0)
#ax.plot_surface(U, V, Z,  cmap='Blues', linewidth=0)
plt.show()

# %%
# 関数グラフのみ
# Only the graph of function

# fig04-03 right

plt.figure(figsize=(8,8))
plt.contourf(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200], cmap='Blues')
C = plt.contour(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200],colors='k')
plt.clabel(C, inline=1, fontsize=10, fmt='%r')
plt.gca().set_aspect('equal')
plt.xticks(range(-4,5,1))
plt.yticks(range(-4,5,1))
plt.xlabel('u', fontsize=14)
plt.ylabel('v', fontsize=14)
plt.grid(linewidth=2)
plt.show()

# %% [markdown]
# # 初期状態
# # Initial state

# %%
n_loop = 1

# %%
# fig-04-07-1
WW1 = np.array(W1[:n_loop])
WW2 = np.array(W2[:n_loop])
ZZ = L(WW1, WW2)
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.set_zlim(0,250)
ax.set_xlabel('u', fontsize=14)
ax.set_ylabel('v', fontsize=14)
ax.set_zlabel('L(u,v)', fontsize=14)
ax.view_init(50, 240)
ax.xaxis._axinfo["grid"]['linewidth'] = 2.
ax.yaxis._axinfo["grid"]['linewidth'] = 2.
ax.zaxis._axinfo["grid"]['linewidth'] = 2.
ax.contour3D(U, V, Z, 100, cmap='Blues', alpha=0.7)
ax.plot3D(WW1, WW2, ZZ, 'o-', c='k', alpha=1, markersize=7)
plt.show()

# %%
# fig04-07-2
plt.figure(figsize=(8,8))
plt.contourf(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200], cmap='Blues')
C = plt.contour(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200],colors='k')
plt.clabel(C, inline=1, fontsize=10, fmt='%r')
plt.gca().set_aspect('equal')
plt.plot(W1[:n_loop], W2[:n_loop], '-o', c='k')
plt.xticks(range(-4,5,1))
plt.yticks(range(-4,5,1))
plt.xlabel('u', fontsize=14)
plt.ylabel('v', fontsize=14)
plt.grid(linewidth=2)
plt.show()

# %% [markdown]
# # 第1ステップ
# # 1st step

# %%
n_loop = 2

# %%
# fig04-08-1
WW1 = np.array(W1[:n_loop])
WW2 = np.array(W2[:n_loop])
ZZ = L(WW1, WW2)
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.set_zlim(0,250)
ax.set_xlabel('u', fontsize=14)
ax.set_ylabel('v', fontsize=14)
ax.set_zlabel('L(u,v)', fontsize=14)
ax.view_init(50, 240)
ax.xaxis._axinfo["grid"]['linewidth'] = 2.
ax.yaxis._axinfo["grid"]['linewidth'] = 2.
ax.zaxis._axinfo["grid"]['linewidth'] = 2.
ax.contour3D(U, V, Z, 100, cmap='Blues', alpha=0.7)
ax.plot3D(WW1, WW2, ZZ, 'o-', c='k', alpha=1, markersize=7)
plt.show()

# %%
# fig04-08-2
plt.figure(figsize=(8,8))
plt.contourf(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200], cmap='Blues')
C = plt.contour(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200],colors='k')
plt.clabel(C, inline=1, fontsize=10, fmt='%r')
plt.plot(W1[:n_loop], W2[:n_loop], '-o', c='k')
plt.gca().set_aspect('equal')
plt.xticks(range(-4,5,1))
plt.yticks(range(-4,5,1))
plt.xlabel('u', fontsize=14)
plt.ylabel('v', fontsize=14)
plt.grid(linewidth=2)
plt.show()

# %% [markdown]
# # step5
# # 5th step

# %%
n_loop = 6

# %%
# fig04-09-1
WW1 = np.array(W1[:n_loop])
WW2 = np.array(W2[:n_loop])
ZZ = L(WW1, WW2)
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.set_zlim(0,250)
ax.set_xlabel('u', fontsize=14)
ax.set_ylabel('v', fontsize=14)
ax.set_zlabel('L(u,v)', fontsize=14)
ax.view_init(50, 240)
ax.xaxis._axinfo["grid"]['linewidth'] = 2.
ax.yaxis._axinfo["grid"]['linewidth'] = 2.
ax.zaxis._axinfo["grid"]['linewidth'] = 2.
ax.contour3D(U, V, Z, 100, cmap='Blues', alpha=0.7)
ax.plot3D(WW1, WW2, ZZ, 'o-', c='k', alpha=1, markersize=7)
plt.show()

# %%
# fig04-09-2
plt.figure(figsize=(8,8))
plt.contourf(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200], cmap='Blues')
C = plt.contour(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200],colors='k')
plt.clabel(C, inline=1, fontsize=10, fmt='%r')
plt.plot(W1[:n_loop], W2[:n_loop], '-o', c='k')
plt.gca().set_aspect('equal')
plt.xticks(range(-4,5,1))
plt.yticks(range(-4,5,1))
plt.xlabel('u', fontsize=14)
plt.ylabel('v', fontsize=14)
plt.grid(linewidth=2)
plt.show()

# %% [markdown]
# # step20
# # 20th step

# %%
n_loop = 21

# %%
# fig04-10-1
WW1 = np.array(W1[:n_loop])
WW2 = np.array(W2[:n_loop])
ZZ = L(WW1, WW2)
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.set_zlim(0,250)
ax.set_xlabel('u', fontsize=14)
ax.set_ylabel('v', fontsize=14)
ax.set_zlabel('L(u,v)', fontsize=14)
ax.view_init(50, 240)
ax.xaxis._axinfo["grid"]['linewidth'] = 2.
ax.yaxis._axinfo["grid"]['linewidth'] = 2.
ax.zaxis._axinfo["grid"]['linewidth'] = 2.
ax.contour3D(U, V, Z, 100, cmap='Blues', alpha=0.7)
ax.plot3D(WW1, WW2, ZZ, 'o-', c='k', alpha=1, markersize=7)
plt.show()

# %%
# fig04-10-2
plt.figure(figsize=(8,8))
plt.contourf(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200], cmap='Blues')
C = plt.contour(U, V, Z, levels=[5,10,20,30,40,50,70,100, 200],colors='k')
plt.clabel(C, inline=1, fontsize=10, fmt='%r')
plt.plot(W1, W2, '-o', c='k')
plt.gca().set_aspect('equal')
plt.xticks(range(-4,5,1))
plt.yticks(range(-4,5,1))
plt.xlabel('u', fontsize=14)
plt.ylabel('v', fontsize=14)
plt.grid(linewidth=2)
plt.show()

# %% [markdown]
# ## 図4-12
# ## Figure 4-12

# %%
def f(x):
    return x**2
def diff(x):
    return 2*x

# %%
x = np.linspace(-2.5, 2.5, 101)
y = f(x)

# %%
a1 = 2
b1 = f(a1)
d1 = diff(a1) * 0.1
a2 = 1.5
b2 = f(a2)
d2 = diff(a2) * 0.1
a3 = 1
b3 = f(a3)
d3 = diff(a3) * 0.1
a4 = 0.5
b4 = f(a4)
d4 = diff(a4) * 0.1

# %%
plt.figure(figsize=(8,8))
plt.plot(x, y)
plt.arrow(a1, b1, -d1, 0, head_width=0.1, head_length=0.1, color='k')
plt.arrow(a2, b2, -d2, 0, head_width=0.1, head_length=0.1, color='k')
plt.arrow(a3, b3, -d3, 0, head_width=0.1, head_length=0.1, color='k')
plt.arrow(a4, b4, -d4, 0, head_width=0.1, head_length=0.1, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ## 図4-13
# ## Figure 4-13

# %%
def L(u, v):
    return 3 * u**2 + 3 * v**2 - u*v + 7*u - 7*v + 10

# %%
def Lu(u, v):
    return 6* u - v + 7

# %%
def Lv(u, v):
    return -u + 6 * v - 7

# %%
u = np.linspace(-5, 5, 11)
v = np.linspace(-5, 5, 11)
U, V = np.meshgrid(u, v)
Z = L(U, V)

# %%
Luu = Lu(U, V)
Lvv = Lv(U, V)

# %%
plt.figure(figsize=(8,8))
plt.quiver(U, V, -Luu, -Lvv)
plt.xticks(np.arange(-5,5,1))
plt.yticks(np.arange(-5,5,1))
plt.scatter([-1],[1],s=80, c='k')
plt.grid()
plt.show()

# %% [markdown]
# ## コラム

# %%
def f(x):
    return 3*x**4 + 4*x**3 - 12*x**2

# %%
def diff(x):
    return x**3 + x**2 - x

# %%
xx = np.linspace(-3, 2, 101)
yy = f(xx)

# %%
a1 = 0.5
a2 = -0.5

# %%
plt.figure(figsize=(6,6))
plt.xticks(color="None")
plt.yticks(color="None")
plt.tick_params(length=0)
plt.plot(xx, yy)
plt.scatter([a1],[f(a1)], s=50, c='k', label='A')
plt.scatter([a2],[f(a2)], s=50, c='b', label='B')
plt.scatter([-2, 1],[f(-2), f(1)], s=50, c='k')
plt.quiver([a1, a2],[f(a1), f(a2)], [diff(a1), diff(a2)],[0, 0])
plt.show()
